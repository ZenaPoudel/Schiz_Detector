# %% [markdown]
# <a href="https://colab.research.google.com/github/ZenaPoudel/Schiz_Detector/blob/main/Copy_of_MCIC_T1_skull_strip_0_3_99%2C99%2C99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ZenaPoudel/Schiz_Detector
# Out:
# Cloning into 'Schiz_Detector'...
# remote: Enumerating objects: 306, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 306 (delta 82), reused 0 (delta 0), pack-reused 188
# Receiving objects: 100% (306/306), 274.65 KiB | 3.48 MiB/s, done.
# Resolving deltas: 100% (204/204), done.

# %%
pip install monai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 18.6 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install nibabel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install pytorch-ignite
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 264 kB 20.8 MB/s
# ...

# %%
# !python /content/Schiz_Detector/trainer/train.py --epoch=30
# Out:
# ----------
# epoch 1/30
# 1/47, train loss: 0.6941, train_accuracy: 0.3750, train_precision: 0.7500, train_recall: 0.4286, train_F1: 0.5455
# 2/47, train loss: 0.7217, train_accuracy: 0.6250, train_precision: 0.6250, train_recall: 1.0000, train_F1: 0.7692
# 3/47, train loss: 0.7259, train_accuracy: 0.6250, train_precision: 0.6250, train_recall: 1.0000, train_F1: 0.7692
# 4/47, train loss: 0.6920, train_accuracy: 0.6250, train_precision: 0.6250, train_recall: 1.0000, train_F1: 0.7692
# 5/47, train loss: 0.6741, train_accuracy: 0.6250, train_precision: 0.6250, train_recall: 1.0000, train_F1: 0.7692
# 6/47, train loss: 0.8252, train_accuracy: 0.3750, train_precision: 0.3750, train_recall: 1.0000, train_F1: 0.5455
# 7/47, train loss: 0.7569, train_accuracy: 0.3750, train_precision: 0.3750, train_recall: 1.0000, train_F1: 0.5455
# 8/47, train loss: 0.7498, train_accuracy: 0.2500, train_precision: 0.2500, train_recall: 1.0000, train_F1: 0.4000
# ...

# %%
# !python /content/Schiz_Detector/test/view_heatmap.py --visualize='3d' --view='axial' --image_path='/content/drive/MyDrive/schizophrenia_data/MCIC_/MCICShare/sub-A00036136/ses-20050101/anat/sub-A00036136_ses-20050101_acq-mprage_run-01_T1w.nii' --image_label=0 --state_dict_path='/content/best_metric_model_classification3d_array_t1.pth'
